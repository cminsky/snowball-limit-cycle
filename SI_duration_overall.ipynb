# %%
from model import *
from helpers import *

# %%
# extract end time of last snowball
def get_last_snowball_end_time(results):
    t = results['t']
    snowball = results['snowball']
    _, ends, _, _ = get_times(t, snowball)
    if ends:
        return ends[-1]
    return np.nan

# %%
def sweep_grid(C_imb_array, tau_array,
               Cimb_min_guess=0.4,
               max_t_max=100,
               dt=1e4/1e6):
    Cimb_min_guess = 0.4

    n_tau = len(tau_array)
    n_c   = len(C_imb_array)
    dur_grid = np.full((n_tau, n_c), np.nan, dtype=float)

    for i, tau in enumerate(tau_array):
        for j, C_imb in enumerate(C_imb_array):
            guess_duration = -tau * np.log(Cimb_min_guess / C_imb)
            t_max = guess_duration + 10
            if guess_duration > max_t_max:
                continue

            print(f"Running tau={tau:0.1f}, C_imb={C_imb:0.1f}, est. dur={guess_duration:0.0f} Myr...", end=" ")
            results = run_model(W_LIP=C_imb, tau=tau, PC_LIP=0, t_max=t_max, dt=dt)

            total_duration = get_last_snowball_end_time(results)
            print(f"→ total {total_duration:.1f} Myr")

            dur_grid[i, j] = total_duration

    run_count = np.isfinite(dur_grid).sum()
    total_possible = dur_grid.size
    print(f"\nCompleted sweep: tried {run_count} / {total_possible} grid points "
          f"({100 * run_count / total_possible:.1f}%)")

    return dur_grid

# %%
Cimb_arr = np.linspace(1, 40, 20)
tau_arr  = np.linspace(10, 80, 20)
dur_grid = sweep_grid(Cimb_arr, tau_arr)
# Out:
# Running tau=10.0, C_imb=1.0, est. dur=9 Myr... → total 3.9 Myr; interglacial nan Myr
# Running tau=10.0, C_imb=3.1, est. dur=20 Myr... → total 10.4 Myr; interglacial 4.5 Myr
# Running tau=10.0, C_imb=5.1, est. dur=25 Myr... → total 16.2 Myr; interglacial 4.6 Myr
# Running tau=10.0, C_imb=7.2, est. dur=29 Myr... → total 22.4 Myr; interglacial 5.4 Myr
# Running tau=10.0, C_imb=9.2, est. dur=31 Myr... → total 30.1 Myr; interglacial 7.3 Myr
# Running tau=10.0, C_imb=11.3, est. dur=33 Myr... → total 26.6 Myr; interglacial 5.3 Myr
# Running tau=10.0, C_imb=13.3, est. dur=35 Myr... → total 24.7 Myr; interglacial 4.4 Myr
# Running tau=10.0, C_imb=15.4, est. dur=36 Myr... → total 32.0 Myr; interglacial 6.1 Myr
# Running tau=10.0, C_imb=17.4, est. dur=38 Myr... → total 30.0 Myr; interglacial 5.1 Myr
# Running tau=10.0, C_imb=19.5, est. dur=39 Myr... → total 28.5 Myr; interglacial 4.4 Myr
# Running tau=10.0, C_imb=21.5, est. dur=40 Myr... → total 36.7 Myr; interglacial 6.5 Myr
# Running tau=10.0, C_imb=23.6, est. dur=41 Myr... → total 34.9 Myr; interglacial 5.6 Myr
# Running tau=10.0, C_imb=25.6, est. dur=42 Myr... → total 33.5 Myr; interglacial 5.0 Myr
# Running tau=10.0, C_imb=27.7, est. dur=42 Myr... → total 32.6 Myr; interglacial 4.5 Myr
# Running tau=10.0, C_imb=29.7, est. dur=43 Myr... → total 41.4 Myr; interglacial 7.1 Myr
# Running tau=10.0, C_imb=31.8, est. dur=44 Myr... → total 39.8 Myr; interglacial 6.2 Myr
# Running tau=10.0, C_imb=33.8, est. dur=44 Myr... → total 38.7 Myr; interglacial 5.7 Myr
# Running tau=10.0, C_imb=35.9, est. dur=45 Myr... → total 37.5 Myr; interglacial 5.1 Myr
# Running tau=10.0, C_imb=37.9, est. dur=46 Myr... → total 36.7 Myr; interglacial 4.8 Myr
# Running tau=10.0, C_imb=40.0, est. dur=46 Myr... → total 36.0 Myr; interglacial 4.5 Myr
# Running tau=13.7, C_imb=1.0, est. dur=13 Myr... → total 3.9 Myr; interglacial nan Myr
# Running tau=13.7, C_imb=3.1, est. dur=28 Myr... → total 18.3 Myr; interglacial 5.7 Myr
# Running tau=13.7, C_imb=5.1, est. dur=35 Myr... → total 34.3 Myr; interglacial 8.7 Myr
# Running tau=13.7, C_imb=7.2, est. dur=39 Myr... → total 27.9 Myr; interglacial 5.2 Myr
# Running tau=13.7, C_imb=9.2, est. dur=43 Myr... → total 33.5 Myr; interglacial 5.7 Myr
# Running tau=13.7, C_imb=11.3, est. dur=46 Myr... → total 39.8 Myr; interglacial 6.6 Myr
# Running tau=13.7, C_imb=13.3, est. dur=48 Myr... → total 36.4 Myr; interglacial 5.2 Myr
# Running tau=13.7, C_imb=15.4, est. dur=50 Myr... → total 43.2 Myr; interglacial 6.4 Myr
# Running tau=13.7, C_imb=17.4, est. dur=52 Myr... → total 40.6 Myr; interglacial 5.3 Myr
# Running tau=13.7, C_imb=19.5, est. dur=53 Myr... → total 48.1 Myr; interglacial 6.9 Myr
# Running tau=13.7, C_imb=21.5, est. dur=55 Myr... → total 45.5 Myr; interglacial 5.8 Myr
# Running tau=13.7, C_imb=23.6, est. dur=56 Myr... → total 54.9 Myr; interglacial 8.6 Myr
# Running tau=13.7, C_imb=25.6, est. dur=57 Myr... → total 51.7 Myr; interglacial 6.8 Myr
# Running tau=13.7, C_imb=27.7, est. dur=58 Myr... → total 49.7 Myr; interglacial 6.0 Myr
# Running tau=13.7, C_imb=29.7, est. dur=59 Myr... → total 47.9 Myr; interglacial 5.4 Myr
# Running tau=13.7, C_imb=31.8, est. dur=60 Myr... → total 57.1 Myr; interglacial 7.7 Myr
# Running tau=13.7, C_imb=33.8, est. dur=61 Myr... → total 55.0 Myr; interglacial 6.7 Myr
# Running tau=13.7, C_imb=35.9, est. dur=62 Myr... → total 53.3 Myr; interglacial 6.0 Myr
# Running tau=13.7, C_imb=37.9, est. dur=62 Myr... → total 51.9 Myr; interglacial 5.5 Myr
# Running tau=13.7, C_imb=40.0, est. dur=63 Myr... → total 62.5 Myr; interglacial 8.8 Myr
# Running tau=17.4, C_imb=1.0, est. dur=16 Myr... → total 3.9 Myr; interglacial nan Myr
# Running tau=17.4, C_imb=3.1, est. dur=35 Myr... → total 26.7 Myr; interglacial 6.6 Myr
# Running tau=17.4, C_imb=5.1, est. dur=44 Myr... → total 40.1 Myr; interglacial 7.9 Myr
# Running tau=17.4, C_imb=7.2, est. dur=50 Myr... → total 43.3 Myr; interglacial 7.1 Myr
# Running tau=17.4, C_imb=9.2, est. dur=54 Myr... → total 47.7 Myr; interglacial 7.1 Myr
# Running tau=17.4, C_imb=11.3, est. dur=58 Myr... → total 53.4 Myr; interglacial 7.7 Myr
# Running tau=17.4, C_imb=13.3, est. dur=61 Myr... → total 48.3 Myr; interglacial 5.8 Myr
# Running tau=17.4, C_imb=15.4, est. dur=63 Myr... → total 54.4 Myr; interglacial 6.6 Myr
# Running tau=17.4, C_imb=17.4, est. dur=66 Myr... → total 61.8 Myr; interglacial 8.0 Myr
# Running tau=17.4, C_imb=19.5, est. dur=67 Myr... → total 57.7 Myr; interglacial 6.4 Myr
# Running tau=17.4, C_imb=21.5, est. dur=69 Myr... → total 65.7 Myr; interglacial 8.1 Myr
# Running tau=17.4, C_imb=23.6, est. dur=71 Myr... → total 62.1 Myr; interglacial 6.7 Myr
# Running tau=17.4, C_imb=25.6, est. dur=72 Myr... → total 59.5 Myr; interglacial 5.8 Myr
# Running tau=17.4, C_imb=27.7, est. dur=74 Myr... → total 67.6 Myr; interglacial 7.3 Myr
# Running tau=17.4, C_imb=29.7, est. dur=75 Myr... → total 64.9 Myr; interglacial 6.4 Myr
# Running tau=17.4, C_imb=31.8, est. dur=76 Myr... → total 76.2 Myr; interglacial 10.5 Myr
# Running tau=17.4, C_imb=33.8, est. dur=77 Myr... → total 71.6 Myr; interglacial 7.5 Myr
# Running tau=17.4, C_imb=35.9, est. dur=78 Myr... → total 69.2 Myr; interglacial 6.6 Myr
# Running tau=17.4, C_imb=37.9, est. dur=79 Myr... → total 67.4 Myr; interglacial 6.1 Myr
# Running tau=17.4, C_imb=40.0, est. dur=80 Myr... → total 77.2 Myr; interglacial 8.5 Myr
# Running tau=21.1, C_imb=1.0, est. dur=19 Myr... → total 15.0 Myr; interglacial 8.4 Myr
# Running tau=21.1, C_imb=3.1, est. dur=43 Myr... → total 35.3 Myr; interglacial 7.5 Myr
# Running tau=21.1, C_imb=5.1, est. dur=54 Myr... → total 46.5 Myr; interglacial 7.6 Myr
# Running tau=21.1, C_imb=7.2, est. dur=61 Myr... → total 48.3 Myr; interglacial 6.5 Myr
# Running tau=21.1, C_imb=9.2, est. dur=66 Myr... → total 63.4 Myr; interglacial 9.2 Myr
# Running tau=21.1, C_imb=11.3, est. dur=70 Myr... → total 67.4 Myr; interglacial 9.1 Myr
# Running tau=21.1, C_imb=13.3, est. dur=74 Myr... → total 60.3 Myr; interglacial 6.3 Myr
# Running tau=21.1, C_imb=15.4, est. dur=77 Myr... → total 65.7 Myr; interglacial 6.7 Myr
# Running tau=21.1, C_imb=17.4, est. dur=79 Myr... → total 71.8 Myr; interglacial 7.5 Myr
# Running tau=21.1, C_imb=19.5, est. dur=82 Myr... → total 79.5 Myr; interglacial 9.4 Myr
# Running tau=21.1, C_imb=21.5, est. dur=84 Myr... → total 74.0 Myr; interglacial 7.0 Myr
# Running tau=21.1, C_imb=23.6, est. dur=86 Myr... → total 82.0 Myr; interglacial 8.7 Myr
# Running tau=21.1, C_imb=25.6, est. dur=88 Myr... → total 77.8 Myr; interglacial 7.0 Myr
# Running tau=21.1, C_imb=27.7, est. dur=89 Myr... → total 86.8 Myr; interglacial 9.4 Myr
# Running tau=21.1, C_imb=29.7, est. dur=91 Myr... → total 82.5 Myr; interglacial 7.4 Myr
# Running tau=21.1, C_imb=31.8, est. dur=92 Myr... → total 79.5 Myr; interglacial 6.5 Myr
# Running tau=21.1, C_imb=33.8, est. dur=93 Myr... → total 88.3 Myr; interglacial 8.3 Myr
# Running tau=21.1, C_imb=35.9, est. dur=95 Myr... → total 85.2 Myr; interglacial 7.1 Myr
# Running tau=21.1, C_imb=37.9, est. dur=96 Myr... → total 83.0 Myr; interglacial 6.5 Myr
# Running tau=21.1, C_imb=40.0, est. dur=97 Myr... → total 92.5 Myr; interglacial 8.5 Myr
# Running tau=24.7, C_imb=1.0, est. dur=23 Myr... → total 14.4 Myr; interglacial 7.8 Myr
# Running tau=24.7, C_imb=3.1, est. dur=50 Myr... → total 44.4 Myr; interglacial 8.4 Myr
# Running tau=24.7, C_imb=5.1, est. dur=63 Myr... → total 52.9 Myr; interglacial 7.4 Myr
# Running tau=24.7, C_imb=7.2, est. dur=71 Myr... → total 64.5 Myr; interglacial 8.2 Myr
# Running tau=24.7, C_imb=9.2, est. dur=78 Myr... → total 65.8 Myr; interglacial 7.1 Myr
# Running tau=24.7, C_imb=11.3, est. dur=83 Myr... → total 68.7 Myr; interglacial 6.7 Myr
# Running tau=24.7, C_imb=13.3, est. dur=87 Myr... → total 72.5 Myr; interglacial 6.7 Myr
# Running tau=24.7, C_imb=15.4, est. dur=90 Myr... → total 76.9 Myr; interglacial 6.8 Myr
# Running tau=24.7, C_imb=17.4, est. dur=93 Myr... → total 82.1 Myr; interglacial 7.2 Myr
# Running tau=24.7, C_imb=19.5, est. dur=96 Myr... → total 87.9 Myr; interglacial 7.9 Myr
# Running tau=24.7, C_imb=21.5, est. dur=99 Myr... → total 95.3 Myr; interglacial 9.6 Myr
# Running tau=28.4, C_imb=1.0, est. dur=26 Myr... → total 14.1 Myr; interglacial 7.5 Myr
# Running tau=28.4, C_imb=3.1, est. dur=58 Myr... → total 54.1 Myr; interglacial 9.9 Myr
# Running tau=28.4, C_imb=5.1, est. dur=72 Myr... → total 59.6 Myr; interglacial 7.3 Myr
# Running tau=28.4, C_imb=7.2, est. dur=82 Myr... → total 69.1 Myr; interglacial 7.3 Myr
# Running tau=28.4, C_imb=9.2, est. dur=89 Myr... → total 80.6 Myr; interglacial 8.2 Myr
# Running tau=28.4, C_imb=11.3, est. dur=95 Myr... → total 82.0 Myr; interglacial 7.3 Myr
# Running tau=28.4, C_imb=13.3, est. dur=100 Myr... → total 84.6 Myr; interglacial 7.0 Myr
# Running tau=32.1, C_imb=1.0, est. dur=29 Myr... → total 13.8 Myr; interglacial 7.2 Myr
# Running tau=32.1, C_imb=3.1, est. dur=65 Myr... → total 50.0 Myr; interglacial 7.3 Myr
# Running tau=32.1, C_imb=5.1, est. dur=82 Myr... → total 66.2 Myr; interglacial 7.3 Myr
# Running tau=32.1, C_imb=7.2, est. dur=93 Myr... → total 86.0 Myr; interglacial 9.2 Myr
# Running tau=35.8, C_imb=1.0, est. dur=33 Myr... → total 25.8 Myr; interglacial 9.4 Myr
# Running tau=35.8, C_imb=3.1, est. dur=73 Myr... → total 58.6 Myr; interglacial 7.8 Myr
# Running tau=35.8, C_imb=5.1, est. dur=91 Myr... → total 85.4 Myr; interglacial 10.0 Myr
# Running tau=39.5, C_imb=1.0, est. dur=36 Myr... → total 25.0 Myr; interglacial 8.7 Myr
# Running tau=39.5, C_imb=3.1, est. dur=80 Myr... → total 67.5 Myr; interglacial 8.4 Myr
# Running tau=43.2, C_imb=1.0, est. dur=40 Myr... → total 24.5 Myr; interglacial 8.3 Myr
# Running tau=43.2, C_imb=3.1, est. dur=88 Myr... → total 76.5 Myr; interglacial 9.0 Myr
# Running tau=46.8, C_imb=1.0, est. dur=43 Myr... → total 24.1 Myr; interglacial 8.0 Myr
# Running tau=46.8, C_imb=3.1, est. dur=95 Myr... → total 85.8 Myr; interglacial 9.8 Myr
# Running tau=50.5, C_imb=1.0, est. dur=46 Myr... → total 36.6 Myr; interglacial 10.1 Myr
# Running tau=54.2, C_imb=1.0, est. dur=50 Myr... → total 35.5 Myr; interglacial 9.2 Myr
# Running tau=57.9, C_imb=1.0, est. dur=53 Myr... → total 34.9 Myr; interglacial 8.7 Myr
# Running tau=61.6, C_imb=1.0, est. dur=56 Myr... → total 34.4 Myr; interglacial 8.4 Myr
# Running tau=65.3, C_imb=1.0, est. dur=60 Myr... → total 47.3 Myr; interglacial 10.5 Myr
# Running tau=68.9, C_imb=1.0, est. dur=63 Myr... → total 46.1 Myr; interglacial 9.6 Myr
# Running tau=72.6, C_imb=1.0, est. dur=67 Myr... → total 45.4 Myr; interglacial 9.1 Myr
# Running tau=76.3, C_imb=1.0, est. dur=70 Myr... → total 44.8 Myr; interglacial 8.8 Myr
# Running tau=80.0, C_imb=1.0, est. dur=73 Myr... → total 58.0 Myr; interglacial 10.9 Myr
#
# Completed sweep: tried 120 / 400 grid points (30.0%)

# %%
fig = plt.figure(figsize=(4.18, 3))
ax = fig.add_axes([0, 0, 1, 1])

vmin, vmax = np.nanmin(dur_grid), np.nanmax(dur_grid)
cs = ax.contour(Cimb_arr, tau_arr, dur_grid,
                levels=[30, 40, 70, 80], cmap="viridis",
                vmin=vmin, vmax=vmax, linewidths=1.5)
ax.clabel(cs, inline=True, fontsize=8, fmt='%0.0f Myr')

cs = ax.contour(Cimb_arr, tau_arr, dur_grid,
                levels=[56], colors="k", vmin=vmin, vmax=vmax, linewidths=1.5)
ax.clabel(cs, inline=True, fontsize=8, fmt='%0.0f Myr')

ax.set_title("Total limit cycle duration")
ax.set_xlabel("C$_{imb}$ [Tmol/yr]")
ax.set_ylabel("$\\tau$ [Myr]")

figname = "total_dur.pdf"
savefig(fig, figname, savefmt='pdf', supp_folder="supp")
plt.show()
